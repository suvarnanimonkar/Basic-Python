# %%
import pandas as pd

# %%
import numpy as np

# %%
d={
    'Name':['suvarna','komal','vidya','divya','shubhu','ranu','rani','sonu','sima',
            'akku','praju','komu'],
    'Age':[32,24,34,35,65,12,34,34,23,22,22,34,],
    'Score':[98,78,98,77,76,58,56,45,35,35,76,34]
}
df=pd.DataFrame(d)
df
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
df.sort_values(by='Score')
# Out:
#        Name  Age  Score
# 11     komu   34     34
# 8      sima   23     35
# 9      akku   22     35
# 7      sonu   34     45
# 6      rani   34     56
# 5      ranu   12     58
# 4    shubhu   65     76
# 10    praju   22     76
# 3     divya   35     77
# 1     komal   24     78
# 0   suvarna   32     98
# 2     vidya   34     98

# %%
df.sort_values(by='Score',ascending=False)
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 2     vidya   34     98
# 1     komal   24     78
# 3     divya   35     77
# 4    shubhu   65     76
# 10    praju   22     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 11     komu   34     34

# %%
df1=df.sort_index()
df1
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
df2=df.sort_index(ascending=False)
df2
# Out:
#        Name  Age  Score
# 11     komu   34     34
# 10    praju   22     76
# 9      akku   22     35
# 8      sima   23     35
# 7      sonu   34     45
# 6      rani   34     56
# 5      ranu   12     58
# 4    shubhu   65     76
# 3     divya   35     77
# 2     vidya   34     98
# 1     komal   24     78
# 0   suvarna   32     98

# %%
df.head()
# Out:
#       Name  Age  Score
# 0  suvarna   32     98
# 1    komal   24     78
# 2    vidya   34     98
# 3    divya   35     77
# 4   shubhu   65     76

# %%
df.drop('Age',axis=1)
# Out:
#        Name  Score
# 0   suvarna     98
# 1     komal     78
# 2     vidya     98
# 3     divya     77
# 4    shubhu     76
# 5      ranu     58
# 6      rani     56
# 7      sonu     45
# 8      sima     35
# 9      akku     35
# 10    praju     76
# 11     komu     34

# %%
df.head()
# Out:
#       Name  Age  Score
# 0  suvarna   32     98
# 1    komal   24     78
# 2    vidya   34     98
# 3    divya   35     77
# 4   shubhu   65     76

# %%
df.drop(['Age','Score'],axis=1)
# Out:
#        Name
# 0   suvarna
# 1     komal
# 2     vidya
# 3     divya
# 4    shubhu
# 5      ranu
# 6      rani
# 7      sonu
# 8      sima
# 9      akku
# 10    praju
# 11     komu

# %%
df.head()
# Out:
#       Name  Age  Score
# 0  suvarna   32     98
# 1    komal   24     78
# 2    vidya   34     98
# 3    divya   35     77
# 4   shubhu   65     76

# %%
df.drop(df.columns[1],axis=1)
# Out:
#        Name  Score
# 0   suvarna     98
# 1     komal     78
# 2     vidya     98
# 3     divya     77
# 4    shubhu     76
# 5      ranu     58
# 6      rani     56
# 7      sonu     45
# 8      sima     35
# 9      akku     35
# 10    praju     76
# 11     komu     34

# %%
df=df.drop(2,axis=0)
df
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
del df['Age']
df
# Out:
#        Name  Score
# 0   suvarna     98
# 1     komal     78
# 3     divya     77
# 4    shubhu     76
# 5      ranu     58
# 6      rani     56
# 7      sonu     45
# 8      sima     35
# 9      akku     35
# 10    praju     76
# 11     komu     34

# %%
import numpy as np
d={
    'Name':['suvarna','komal','vidya','divya','shubhu','ranu','rani','sonu','sima',
            'akku','praju','komu'],
    'Age':[32,24,34,35,65,12,34,34,23,22,22,34,],
    'Score':[98,78,98,77,76,58,56,45,35,35,76,34]
}
df=pd.DataFrame(d)
df
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
df.drop_duplicates()
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
df.drop_duplicates(keep='last')
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
#by col
d={
    'Name':['suvarna','komal','vidya','divya','shubhu','ranu','rani','sonu','sima',
            'akku','praju','komu'],
    'Age':[32,24,34,35,65,12,34,34,23,22,22,34,],
    'Score':[98,78,98,77,76,58,56,45,35,35,76,34]
}
df=pd.DataFrame(d)
df
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34

# %%
df.drop_duplicates()
# Out:
#        Name  Age  Score
# 0   suvarna   32     98
# 1     komal   24     78
# 2     vidya   34     98
# 3     divya   35     77
# 4    shubhu   65     76
# 5      ranu   12     58
# 6      rani   34     56
# 7      sonu   34     45
# 8      sima   23     35
# 9      akku   22     35
# 10    praju   22     76
# 11     komu   34     34
